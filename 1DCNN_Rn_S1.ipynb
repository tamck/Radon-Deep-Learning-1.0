# %%
# %matplotlib inline 

import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

from numpy import array
from numpy import hstack

import tensorflow as tf

from tensorflow.keras.models import Sequential # layer-by-layer construction
from tensorflow.keras.layers import Dense # dense: fully connected layers
from tensorflow.nn import relu, elu # activation functions
from tensorflow.keras.layers import Conv1D, MaxPooling1D 
from tensorflow.keras.layers import Flatten, Dropout  
from tensorflow.keras.layers import Layer, Input

from keras.layers import GRU

from sklearn.metrics import r2_score

# %%
# print package versions
print("numpy version:", np.__version__)
print("tensorflow version:", tf.__version__)
print("pandas version:", pd.__version__)
# Out:
# numpy version: 1.21.6
# tensorflow version: 2.8.2
# pandas version: 1.3.5

# %%
# set random seed for reproducible results
SEED = 42004
np.random.seed(SEED)
tf.random.set_seed(SEED)

tf.compat.v1.set_random_seed(SEED)

# %%
# if using Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Load Kīholo Dataset for 1D-CNN-RNN
#
# Data Sources:
# Dulai, H., Kamenik, J., Waters, C. A., Kennedy, J., Babinec, J., Jolly, J., & Williamson, M. (2016). Autonomous long-term gamma-spectrometric monitoring of submarine groundwater discharge trends in Hawaii. Journal of Radioanalytical and Nuclear Chemistry, 307(3), 1865–1870. https://doi.org/10.1007/s10967-015-4580-9
#
# McKenzie, T., Dulai, H., & Fuleky, P. (2021). Traditional and novel time-series approaches reveal submarine groundwater discharge dynamics under baseline and extreme event conditions. Scientific Reports, 11(1), 1–14. https://doi.org/10.1038/s41598-021-01920-0
#
# Meteorological data: RAWS USA Climate Archive. Puu Waawaa, Hawaii. Accessed from: https://raws.dri.edu/cgi-bin/rawMAIN.pl?hiHPUW

# %%
# load Kiholo dataset for training and validation
# import data
data = pd.read_excel('1DCNN_KiholoRn_clean.xlsx')

data.columns = ['datetime', 'owl_m',
                 'ctdtemp_C', 'ctdsal', 'Rn_Bqm3'] 

# convert first column to datetime format
data.datetime = pd.to_datetime(data.datetime)

# index by datetime
data.set_index(data.datetime, inplace = True)

data = data.drop('datetime', axis = 1)
data.head()
# Out:
#                      owl_m  ctdtemp_C   ctdsal     Rn_Bqm3
# datetime
# 2014-03-14 02:00:00  0.278    24.3675  16.8750  221.610947
# 2014-03-14 03:00:00  0.296    23.7625  15.3425    6.666667
# 2014-03-14 04:00:00  0.269    23.3425  14.3500    6.666667
# 2014-03-14 05:00:00  0.178    22.8300  13.2225    6.666667
# 2014-03-14 06:00:00  0.051    22.6050  13.6600  418.577742

# %%
# pre-processing: 12 hour moving average
data_12hr = data.rolling(window = 12, center = True).mean()
data_12hr = data_12hr.dropna()
data_12hr.head()
# Out:
#                         owl_m  ctdtemp_C     ctdsal     Rn_Bqm3
# datetime
# 2014-03-14 08:00:00  0.003083  23.252083  16.678958  122.365785
# 2014-03-14 09:00:00 -0.009833  23.305625  17.531875  104.453762
# 2014-03-14 10:00:00 -0.022667  23.406042  18.565417  104.453762
# 2014-03-14 11:00:00 -0.034250  23.476458  19.478125  104.453762
# 2014-03-14 12:00:00 -0.043750  23.541458  20.238542  104.453762

# %%
# print minimum values and rescale as needed so minimum is greater than 0
print(min(data_12hr['owl_m']))
print(min(data_12hr['ctdtemp_C']))
print(min(data_12hr['ctdsal']))
print(min(data_12hr['Rn_Bqm3']))

data_12hr['owl_m'] = data_12hr['owl_m'] + abs((min(data_12hr['owl_m'])))
print(min(data_12hr['owl_m']))

data_12hr['Rn_Bqm3'] = data_12hr['Rn_Bqm3'] + abs((min(data_12hr['Rn_Bqm3'])))
print(min(data_12hr['Rn_Bqm3']))
# Out:
# -0.2336666666666667
# 22.304166666666664
# 9.043407155979166
# -41.15864177255233
# 0.0
# 0.0

# %%
# normalize Kiholo data
data_norm = data_12hr
data_norm['owl_m'] = (data_12hr['owl_m'] - min(data_12hr['owl_m'])) / (max(data_12hr['owl_m']) - min(data_12hr['owl_m']))
data_norm['ctdtemp_C'] = (data_12hr['ctdtemp_C'] - min(data_12hr['ctdtemp_C'])) / (max(data_12hr['ctdtemp_C']) - min(data_12hr['ctdtemp_C']))
data_norm['ctdsal'] = (data_12hr['ctdsal'] - min(data_12hr['ctdsal'])) / (max(data_12hr['ctdsal']) - min(data_12hr['ctdsal']))
data_norm['Rn_Bqm3'] = (data_12hr['Rn_Bqm3'] - min(data_12hr['Rn_Bqm3'])) / (max(data_12hr['Rn_Bqm3']) - min(data_12hr['Rn_Bqm3']))

data_norm.head()
# Out:
#                         owl_m  ctdtemp_C    ctdsal   Rn_Bqm3
# datetime
# 2014-03-14 08:00:00  0.409838   0.150373  0.409740  0.104615
# 2014-03-14 09:00:00  0.387478   0.158867  0.455509  0.093156
# 2014-03-14 10:00:00  0.365263   0.174797  0.510971  0.093156
# 2014-03-14 11:00:00  0.345211   0.185967  0.559949  0.093156
# 2014-03-14 12:00:00  0.328765   0.196279  0.600754  0.093156

# %% [markdown]
# # Multistep 1D-CNN-RNN for Kīholo Data

# %%
# code modified from "Deep Learning for Time Series Forecasting: Predict the Future with MLPs, CNNs and LSTMs in Python" by Jason Brownlee
# https://machinelearningmastery.com/deep-learning-for-time-series-forecasting/

# split Kiholo sequence into samples - take each sequence and make from n steps in and out
def split_sequences(sequences, n_steps_in, n_steps_out):
  X, y = list(), list()
  for i in range(len(sequences)):
    # find the end
    end_ix = i + n_steps_in # dataset length + number of steeps fed to model
    out_end_ix = end_ix + n_steps_out # previous step + number of steps to predict
    # stop once outside of dataset length
    if out_end_ix > len(sequences):
      break
    # gather input and output
    seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix:out_end_ix, :]
    X.append(seq_x)
    y.append(seq_y)
  return array(X), array(y)

# define input sequence
in_seq1 = data_norm['owl_m'].to_numpy()
in_seq2 = data_norm['ctdtemp_C'].to_numpy()
in_seq3 = data_norm['ctdsal'].to_numpy()

# define output sequence
out_seq = data_norm['Rn_Bqm3'].to_numpy()

# convert input and output to [rows, columns] structure for CNN
in_seq1 = in_seq1.reshape((len(in_seq1), 1))
in_seq2 = in_seq2.reshape((len(in_seq2), 1))
in_seq3 = in_seq3.reshape((len(in_seq3), 1))

out_seq = out_seq.reshape((len(out_seq), 1))

# horizontally stack input and output columns (ie to windows)
dataset = hstack((in_seq1, in_seq2, in_seq3, out_seq))

# number of time steps in/out
n_steps_in, n_steps_out = 6, 1

# convert into input/output
X, y = split_sequences(dataset, n_steps_in, n_steps_out)
print(X.shape, y.shape)

# flatten output
n_output = y.shape[1] * y.shape[2]
y = y.reshape((y.shape[0], n_output))

# nunber of features
n_features = X.shape[2]

# setup for train/validation split
N = len(X)
t = np.arange(0,N)

# split into training and validation data
# 80/20
Tp_data = int(len(X) * 0.8)
Tp_data
# Out:
# (15328, 6, 4) (15328, 1, 4)
# 12262

# %%
X_train = X[0:Tp_data,:]
y_train = y[0:Tp_data]

X_test = X[Tp_data:N,:]
y_test = y[Tp_data:N]

# %%
# define model
model = Sequential()
model.add(Conv1D(90, 2, activation = 'relu', input_shape = 
                 (n_steps_in, n_features)))
model.add(Conv1D(90, 2, activation = 'relu'))
model.add(MaxPooling1D())

model.add(GRU(20, activation = 'relu', return_sequences = True))
model.add(GRU(20, activation = 'relu', return_sequences = True))
model.add(Flatten())

model.add(Dense(units = 250, activation = 'elu'))
model.add(Dense(units = 125, activation = 'elu'))
model.add(Dense(units = 50, activation = 'elu'))
model.add(Dense(n_output))

# learning rate optimizer
initial_learning_rate = 0.0001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps = 7000,
    decay_rate = 0.94,
    staircase = False) 

# early stopping
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience = 25)

# compile 1D-Conv with learning rate optimizer and early stopping
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate = lr_schedule), 
              loss ='mae', 
              metrics = ['mean_absolute_error', 'RootMeanSquaredError'])

# %%
# Fit the model
hist = model.fit(X_train, y_train, 
                 validation_data = (X_test, y_test), 
                 epochs = 5000, 
                 batch_size = 100, 
                 callbacks = [callback], 
                 verbose = 1)
# Out:
# Epoch 1/5000
# 123/123 [==============================] - 5s 16ms/step - loss: 0.1794 - mean_absolute_error: 0.1794 - root_mean_squared_error: 0.2401 - val_loss: 0.0978 - val_mean_absolute_error: 0.0978 - val_root_mean_squared_error: 0.1208
# Epoch 2/5000
# 123/123 [==============================] - 2s 12ms/step - loss: 0.0910 - mean_absolute_error: 0.0910 - root_mean_squared_error: 0.1188 - val_loss: 0.0747 - val_mean_absolute_error: 0.0747 - val_root_mean_squared_error: 0.0944
# Epoch 3/5000
# 123/123 [==============================] - 1s 12ms/step - loss: 0.0651 - mean_absolute_error: 0.0651 - root_mean_squared_error: 0.0854 - val_loss: 0.0556 - val_mean_absolute_error: 0.0556 - val_root_mean_squared_error: 0.0704
# Epoch 4/5000
# 123/123 [==============================] - 2s 17ms/step - loss: 0.0408 - mean_absolute_error: 0.0408 - root_mean_squared_error: 0.0567 - val_loss: 0.0379 - val_mean_absolute_error: 0.0379 - val_root_mean_squared_error: 0.0522
# Epoch 5/5000
# 123/123 [==============================] - 3s 21ms/step - loss: 0.0324 - mean_absolute_error: 0.0324 - root_mean_squared_error: 0.0481 - val_loss: 0.0386 - val_mean_absolute_error: 0.0386 - val_root_mean_squared_error: 0.0530
# Epoch 6/5000
# 123/123 [==============================] - 3s 24ms/step - loss: 0.0308 - mean_absolute_error: 0.0308 - root_mean_squared_error: 0.0464 - val_loss: 0.0365 - val_mean_absolute_error: 0.0365 - val_root_mean_squared_error: 0.0511
# Epoch 7/5000
# 123/123 [==============================] - 3s 23ms/step - loss: 0.0295 - mean_absolute_error: 0.0295 - root_mean_squared_error: 0.0451 - val_loss: 0.0345 - val_mean_absolute_error: 0.0345 - val_root_mean_squared_error: 0.0490
# Epoch 8/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0287 - mean_absolute_error: 0.0287 - root_mean_squared_error: 0.0443 - val_loss: 0.0337 - val_mean_absolute_error: 0.0337 - val_root_mean_squared_error: 0.0479
# Epoch 9/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0275 - mean_absolute_error: 0.0275 - root_mean_squared_error: 0.0432 - val_loss: 0.0335 - val_mean_absolute_error: 0.0335 - val_root_mean_squared_error: 0.0478
# Epoch 10/5000
# 123/123 [==============================] - 2s 12ms/step - loss: 0.0269 - mean_absolute_error: 0.0269 - root_mean_squared_error: 0.0424 - val_loss: 0.0320 - val_mean_absolute_error: 0.0320 - val_root_mean_squared_error: 0.0464
# Epoch 11/5000
# 123/123 [==============================] - 2s 12ms/step - loss: 0.0258 - mean_absolute_error: 0.0258 - root_mean_squared_error: 0.0413 - val_loss: 0.0314 - val_mean_absolute_error: 0.0314 - val_root_mean_squared_error: 0.0456
# Epoch 12/5000
# 123/123 [==============================] - 2s 12ms/step - loss: 0.0249 - mean_absolute_error: 0.0249 - root_mean_squared_error: 0.0404 - val_loss: 0.0310 - val_mean_absolute_error: 0.0310 - val_root_mean_squared_error: 0.0452
# Epoch 13/5000
# 123/123 [==============================] - 1s 12ms/step - loss: 0.0243 - mean_absolute_error: 0.0243 - root_mean_squared_error: 0.0396 - val_loss: 0.0300 - val_mean_absolute_error: 0.0300 - val_root_mean_squared_error: 0.0443
# Epoch 14/5000
# 123/123 [==============================] - 2s 12ms/step - loss: 0.0236 - mean_absolute_error: 0.0236 - root_mean_squared_error: 0.0389 - val_loss: 0.0287 - val_mean_absolute_error: 0.0287 - val_root_mean_squared_error: 0.0432
# Epoch 15/5000
# 123/123 [==============================] - 1s 12ms/step - loss: 0.0226 - mean_absolute_error: 0.0226 - root_mean_squared_error: 0.0380 - val_loss: 0.0282 - val_mean_absolute_error: 0.0282 - val_root_mean_squared_error: 0.0427
# Epoch 16/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0219 - mean_absolute_error: 0.0219 - root_mean_squared_error: 0.0374 - val_loss: 0.0275 - val_mean_absolute_error: 0.0275 - val_root_mean_squared_error: 0.0418
# Epoch 17/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0215 - mean_absolute_error: 0.0215 - root_mean_squared_error: 0.0370 - val_loss: 0.0266 - val_mean_absolute_error: 0.0266 - val_root_mean_squared_error: 0.0411
# Epoch 18/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0211 - mean_absolute_error: 0.0211 - root_mean_squared_error: 0.0366 - val_loss: 0.0260 - val_mean_absolute_error: 0.0260 - val_root_mean_squared_error: 0.0404
# Epoch 19/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0207 - mean_absolute_error: 0.0207 - root_mean_squared_error: 0.0362 - val_loss: 0.0255 - val_mean_absolute_error: 0.0255 - val_root_mean_squared_error: 0.0400
# Epoch 20/5000
# 123/123 [==============================] - 2s 12ms/step - loss: 0.0202 - mean_absolute_error: 0.0202 - root_mean_squared_error: 0.0357 - val_loss: 0.0250 - val_mean_absolute_error: 0.0250 - val_root_mean_squared_error: 0.0395
# Epoch 21/5000
# 123/123 [==============================] - 1s 12ms/step - loss: 0.0198 - mean_absolute_error: 0.0198 - root_mean_squared_error: 0.0354 - val_loss: 0.0244 - val_mean_absolute_error: 0.0244 - val_root_mean_squared_error: 0.0389
# Epoch 22/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0195 - mean_absolute_error: 0.0195 - root_mean_squared_error: 0.0351 - val_loss: 0.0251 - val_mean_absolute_error: 0.0251 - val_root_mean_squared_error: 0.0395
# Epoch 23/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0191 - mean_absolute_error: 0.0191 - root_mean_squared_error: 0.0348 - val_loss: 0.0238 - val_mean_absolute_error: 0.0238 - val_root_mean_squared_error: 0.0383
# Epoch 24/5000
# 123/123 [==============================] - 2s 12ms/step - loss: 0.0188 - mean_absolute_error: 0.0188 - root_mean_squared_error: 0.0345 - val_loss: 0.0237 - val_mean_absolute_error: 0.0237 - val_root_mean_squared_error: 0.0381
# Epoch 25/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0185 - mean_absolute_error: 0.0185 - root_mean_squared_error: 0.0342 - val_loss: 0.0228 - val_mean_absolute_error: 0.0228 - val_root_mean_squared_error: 0.0373
# Epoch 26/5000
# 123/123 [==============================] - 2s 12ms/step - loss: 0.0184 - mean_absolute_error: 0.0184 - root_mean_squared_error: 0.0342 - val_loss: 0.0238 - val_mean_absolute_error: 0.0238 - val_root_mean_squared_error: 0.0378
# Epoch 27/5000
# 123/123 [==============================] - 1s 12ms/step - loss: 0.0183 - mean_absolute_error: 0.0183 - root_mean_squared_error: 0.0340 - val_loss: 0.0230 - val_mean_absolute_error: 0.0230 - val_root_mean_squared_error: 0.0374
# Epoch 28/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0180 - mean_absolute_error: 0.0180 - root_mean_squared_error: 0.0337 - val_loss: 0.0218 - val_mean_absolute_error: 0.0218 - val_root_mean_squared_error: 0.0364
# Epoch 29/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0180 - mean_absolute_error: 0.0180 - root_mean_squared_error: 0.0336 - val_loss: 0.0226 - val_mean_absolute_error: 0.0226 - val_root_mean_squared_error: 0.0368
# Epoch 30/5000
# 123/123 [==============================] - 1s 12ms/step - loss: 0.0176 - mean_absolute_error: 0.0176 - root_mean_squared_error: 0.0334 - val_loss: 0.0218 - val_mean_absolute_error: 0.0218 - val_root_mean_squared_error: 0.0360
# Epoch 31/5000
# 123/123 [==============================] - 1s 12ms/step - loss: 0.0172 - mean_absolute_error: 0.0172 - root_mean_squared_error: 0.0330 - val_loss: 0.0218 - val_mean_absolute_error: 0.0218 - val_root_mean_squared_error: 0.0358
# Epoch 32/5000
# 123/123 [==============================] - 1s 12ms/step - loss: 0.0173 - mean_absolute_error: 0.0173 - root_mean_squared_error: 0.0330 - val_loss: 0.0210 - val_mean_absolute_error: 0.0210 - val_root_mean_squared_error: 0.0353
# Epoch 33/5000
# 123/123 [==============================] - 1s 12ms/step - loss: 0.0172 - mean_absolute_error: 0.0172 - root_mean_squared_error: 0.0328 - val_loss: 0.0207 - val_mean_absolute_error: 0.0207 - val_root_mean_squared_error: 0.0349
# Epoch 34/5000
# 123/123 [==============================] - 1s 12ms/step - loss: 0.0167 - mean_absolute_error: 0.0167 - root_mean_squared_error: 0.0325 - val_loss: 0.0224 - val_mean_absolute_error: 0.0224 - val_root_mean_squared_error: 0.0357
# Epoch 35/5000
# 123/123 [==============================] - 2s 12ms/step - loss: 0.0167 - mean_absolute_error: 0.0167 - root_mean_squared_error: 0.0324 - val_loss: 0.0205 - val_mean_absolute_error: 0.0205 - val_root_mean_squared_error: 0.0345
# Epoch 36/5000
# 123/123 [==============================] - 2s 12ms/step - loss: 0.0164 - mean_absolute_error: 0.0164 - root_mean_squared_error: 0.0322 - val_loss: 0.0213 - val_mean_absolute_error: 0.0213 - val_root_mean_squared_error: 0.0347
# Epoch 37/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0163 - mean_absolute_error: 0.0163 - root_mean_squared_error: 0.0321 - val_loss: 0.0197 - val_mean_absolute_error: 0.0197 - val_root_mean_squared_error: 0.0336
# Epoch 38/5000
# 123/123 [==============================] - 2s 12ms/step - loss: 0.0160 - mean_absolute_error: 0.0160 - root_mean_squared_error: 0.0318 - val_loss: 0.0193 - val_mean_absolute_error: 0.0193 - val_root_mean_squared_error: 0.0332
# Epoch 39/5000
# 123/123 [==============================] - 2s 12ms/step - loss: 0.0158 - mean_absolute_error: 0.0158 - root_mean_squared_error: 0.0317 - val_loss: 0.0205 - val_mean_absolute_error: 0.0205 - val_root_mean_squared_error: 0.0339
# Epoch 40/5000
# 123/123 [==============================] - 2s 12ms/step - loss: 0.0159 - mean_absolute_error: 0.0159 - root_mean_squared_error: 0.0317 - val_loss: 0.0193 - val_mean_absolute_error: 0.0193 - val_root_mean_squared_error: 0.0331
# Epoch 41/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0157 - mean_absolute_error: 0.0157 - root_mean_squared_error: 0.0316 - val_loss: 0.0201 - val_mean_absolute_error: 0.0201 - val_root_mean_squared_error: 0.0331
# Epoch 42/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0157 - mean_absolute_error: 0.0157 - root_mean_squared_error: 0.0315 - val_loss: 0.0187 - val_mean_absolute_error: 0.0187 - val_root_mean_squared_error: 0.0324
# Epoch 43/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0154 - mean_absolute_error: 0.0154 - root_mean_squared_error: 0.0313 - val_loss: 0.0193 - val_mean_absolute_error: 0.0193 - val_root_mean_squared_error: 0.0327
# Epoch 44/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0154 - mean_absolute_error: 0.0154 - root_mean_squared_error: 0.0313 - val_loss: 0.0193 - val_mean_absolute_error: 0.0193 - val_root_mean_squared_error: 0.0326
# Epoch 45/5000
# 123/123 [==============================] - 2s 12ms/step - loss: 0.0154 - mean_absolute_error: 0.0154 - root_mean_squared_error: 0.0313 - val_loss: 0.0187 - val_mean_absolute_error: 0.0187 - val_root_mean_squared_error: 0.0321
# Epoch 46/5000
# 123/123 [==============================] - 3s 21ms/step - loss: 0.0152 - mean_absolute_error: 0.0152 - root_mean_squared_error: 0.0311 - val_loss: 0.0176 - val_mean_absolute_error: 0.0176 - val_root_mean_squared_error: 0.0313
# Epoch 47/5000
# 123/123 [==============================] - 3s 25ms/step - loss: 0.0150 - mean_absolute_error: 0.0150 - root_mean_squared_error: 0.0310 - val_loss: 0.0179 - val_mean_absolute_error: 0.0179 - val_root_mean_squared_error: 0.0314
# Epoch 48/5000
# 123/123 [==============================] - 2s 20ms/step - loss: 0.0150 - mean_absolute_error: 0.0150 - root_mean_squared_error: 0.0309 - val_loss: 0.0185 - val_mean_absolute_error: 0.0185 - val_root_mean_squared_error: 0.0316
# Epoch 49/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0150 - mean_absolute_error: 0.0150 - root_mean_squared_error: 0.0309 - val_loss: 0.0176 - val_mean_absolute_error: 0.0176 - val_root_mean_squared_error: 0.0310
# Epoch 50/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0147 - mean_absolute_error: 0.0147 - root_mean_squared_error: 0.0307 - val_loss: 0.0173 - val_mean_absolute_error: 0.0173 - val_root_mean_squared_error: 0.0307
# Epoch 51/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0146 - mean_absolute_error: 0.0146 - root_mean_squared_error: 0.0306 - val_loss: 0.0171 - val_mean_absolute_error: 0.0171 - val_root_mean_squared_error: 0.0306
# Epoch 52/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0147 - mean_absolute_error: 0.0147 - root_mean_squared_error: 0.0306 - val_loss: 0.0176 - val_mean_absolute_error: 0.0176 - val_root_mean_squared_error: 0.0308
# Epoch 53/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0147 - mean_absolute_error: 0.0147 - root_mean_squared_error: 0.0307 - val_loss: 0.0175 - val_mean_absolute_error: 0.0175 - val_root_mean_squared_error: 0.0305
# Epoch 54/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0145 - mean_absolute_error: 0.0145 - root_mean_squared_error: 0.0305 - val_loss: 0.0173 - val_mean_absolute_error: 0.0173 - val_root_mean_squared_error: 0.0304
# Epoch 55/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0143 - mean_absolute_error: 0.0143 - root_mean_squared_error: 0.0304 - val_loss: 0.0166 - val_mean_absolute_error: 0.0166 - val_root_mean_squared_error: 0.0300
# Epoch 56/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0143 - mean_absolute_error: 0.0143 - root_mean_squared_error: 0.0303 - val_loss: 0.0165 - val_mean_absolute_error: 0.0165 - val_root_mean_squared_error: 0.0298
# Epoch 57/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0142 - mean_absolute_error: 0.0142 - root_mean_squared_error: 0.0303 - val_loss: 0.0167 - val_mean_absolute_error: 0.0167 - val_root_mean_squared_error: 0.0300
# Epoch 58/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0142 - mean_absolute_error: 0.0142 - root_mean_squared_error: 0.0302 - val_loss: 0.0176 - val_mean_absolute_error: 0.0176 - val_root_mean_squared_error: 0.0304
# Epoch 59/5000
# 123/123 [==============================] - 2s 12ms/step - loss: 0.0142 - mean_absolute_error: 0.0142 - root_mean_squared_error: 0.0303 - val_loss: 0.0162 - val_mean_absolute_error: 0.0162 - val_root_mean_squared_error: 0.0295
# Epoch 60/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0143 - mean_absolute_error: 0.0143 - root_mean_squared_error: 0.0303 - val_loss: 0.0163 - val_mean_absolute_error: 0.0163 - val_root_mean_squared_error: 0.0296
# Epoch 61/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0140 - mean_absolute_error: 0.0140 - root_mean_squared_error: 0.0301 - val_loss: 0.0161 - val_mean_absolute_error: 0.0161 - val_root_mean_squared_error: 0.0293
# Epoch 62/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0139 - mean_absolute_error: 0.0139 - root_mean_squared_error: 0.0301 - val_loss: 0.0164 - val_mean_absolute_error: 0.0164 - val_root_mean_squared_error: 0.0295
# Epoch 63/5000
# 123/123 [==============================] - 2s 19ms/step - loss: 0.0140 - mean_absolute_error: 0.0140 - root_mean_squared_error: 0.0301 - val_loss: 0.0166 - val_mean_absolute_error: 0.0166 - val_root_mean_squared_error: 0.0296
# Epoch 64/5000
# 123/123 [==============================] - 2s 16ms/step - loss: 0.0141 - mean_absolute_error: 0.0141 - root_mean_squared_error: 0.0301 - val_loss: 0.0168 - val_mean_absolute_error: 0.0168 - val_root_mean_squared_error: 0.0297
# Epoch 65/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0138 - mean_absolute_error: 0.0138 - root_mean_squared_error: 0.0300 - val_loss: 0.0163 - val_mean_absolute_error: 0.0163 - val_root_mean_squared_error: 0.0292
# Epoch 66/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0137 - mean_absolute_error: 0.0137 - root_mean_squared_error: 0.0299 - val_loss: 0.0160 - val_mean_absolute_error: 0.0160 - val_root_mean_squared_error: 0.0291
# Epoch 67/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0136 - mean_absolute_error: 0.0136 - root_mean_squared_error: 0.0299 - val_loss: 0.0159 - val_mean_absolute_error: 0.0159 - val_root_mean_squared_error: 0.0290
# Epoch 68/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0137 - mean_absolute_error: 0.0137 - root_mean_squared_error: 0.0299 - val_loss: 0.0155 - val_mean_absolute_error: 0.0155 - val_root_mean_squared_error: 0.0287
# Epoch 69/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0137 - mean_absolute_error: 0.0137 - root_mean_squared_error: 0.0299 - val_loss: 0.0158 - val_mean_absolute_error: 0.0158 - val_root_mean_squared_error: 0.0290
# Epoch 70/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0136 - mean_absolute_error: 0.0136 - root_mean_squared_error: 0.0298 - val_loss: 0.0152 - val_mean_absolute_error: 0.0152 - val_root_mean_squared_error: 0.0285
# Epoch 71/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0137 - mean_absolute_error: 0.0137 - root_mean_squared_error: 0.0298 - val_loss: 0.0168 - val_mean_absolute_error: 0.0168 - val_root_mean_squared_error: 0.0294
# Epoch 72/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0138 - mean_absolute_error: 0.0138 - root_mean_squared_error: 0.0299 - val_loss: 0.0160 - val_mean_absolute_error: 0.0160 - val_root_mean_squared_error: 0.0288
# Epoch 73/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0135 - mean_absolute_error: 0.0135 - root_mean_squared_error: 0.0297 - val_loss: 0.0150 - val_mean_absolute_error: 0.0150 - val_root_mean_squared_error: 0.0284
# Epoch 74/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0135 - mean_absolute_error: 0.0135 - root_mean_squared_error: 0.0297 - val_loss: 0.0155 - val_mean_absolute_error: 0.0155 - val_root_mean_squared_error: 0.0286
# Epoch 75/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0134 - mean_absolute_error: 0.0134 - root_mean_squared_error: 0.0297 - val_loss: 0.0159 - val_mean_absolute_error: 0.0159 - val_root_mean_squared_error: 0.0288
# Epoch 76/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0134 - mean_absolute_error: 0.0134 - root_mean_squared_error: 0.0297 - val_loss: 0.0148 - val_mean_absolute_error: 0.0148 - val_root_mean_squared_error: 0.0281
# Epoch 77/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0132 - mean_absolute_error: 0.0132 - root_mean_squared_error: 0.0296 - val_loss: 0.0157 - val_mean_absolute_error: 0.0157 - val_root_mean_squared_error: 0.0286
# Epoch 78/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0134 - mean_absolute_error: 0.0134 - root_mean_squared_error: 0.0296 - val_loss: 0.0154 - val_mean_absolute_error: 0.0154 - val_root_mean_squared_error: 0.0285
# Epoch 79/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0133 - mean_absolute_error: 0.0133 - root_mean_squared_error: 0.0295 - val_loss: 0.0156 - val_mean_absolute_error: 0.0156 - val_root_mean_squared_error: 0.0284
# Epoch 80/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0134 - mean_absolute_error: 0.0134 - root_mean_squared_error: 0.0296 - val_loss: 0.0154 - val_mean_absolute_error: 0.0154 - val_root_mean_squared_error: 0.0284
# Epoch 81/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0132 - mean_absolute_error: 0.0132 - root_mean_squared_error: 0.0294 - val_loss: 0.0157 - val_mean_absolute_error: 0.0157 - val_root_mean_squared_error: 0.0285
# Epoch 82/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0133 - mean_absolute_error: 0.0133 - root_mean_squared_error: 0.0295 - val_loss: 0.0151 - val_mean_absolute_error: 0.0151 - val_root_mean_squared_error: 0.0283
# Epoch 83/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0134 - mean_absolute_error: 0.0134 - root_mean_squared_error: 0.0296 - val_loss: 0.0145 - val_mean_absolute_error: 0.0145 - val_root_mean_squared_error: 0.0278
# Epoch 84/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0131 - mean_absolute_error: 0.0131 - root_mean_squared_error: 0.0294 - val_loss: 0.0148 - val_mean_absolute_error: 0.0148 - val_root_mean_squared_error: 0.0280
# Epoch 85/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0131 - mean_absolute_error: 0.0131 - root_mean_squared_error: 0.0295 - val_loss: 0.0151 - val_mean_absolute_error: 0.0151 - val_root_mean_squared_error: 0.0281
# Epoch 86/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0132 - mean_absolute_error: 0.0132 - root_mean_squared_error: 0.0295 - val_loss: 0.0153 - val_mean_absolute_error: 0.0153 - val_root_mean_squared_error: 0.0282
# Epoch 87/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0129 - mean_absolute_error: 0.0129 - root_mean_squared_error: 0.0293 - val_loss: 0.0144 - val_mean_absolute_error: 0.0144 - val_root_mean_squared_error: 0.0277
# Epoch 88/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0129 - mean_absolute_error: 0.0129 - root_mean_squared_error: 0.0293 - val_loss: 0.0149 - val_mean_absolute_error: 0.0149 - val_root_mean_squared_error: 0.0279
# Epoch 89/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0129 - mean_absolute_error: 0.0129 - root_mean_squared_error: 0.0293 - val_loss: 0.0144 - val_mean_absolute_error: 0.0144 - val_root_mean_squared_error: 0.0276
# Epoch 90/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0128 - mean_absolute_error: 0.0128 - root_mean_squared_error: 0.0293 - val_loss: 0.0150 - val_mean_absolute_error: 0.0150 - val_root_mean_squared_error: 0.0279
# Epoch 91/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0130 - mean_absolute_error: 0.0130 - root_mean_squared_error: 0.0293 - val_loss: 0.0150 - val_mean_absolute_error: 0.0150 - val_root_mean_squared_error: 0.0279
# Epoch 92/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0128 - mean_absolute_error: 0.0128 - root_mean_squared_error: 0.0292 - val_loss: 0.0145 - val_mean_absolute_error: 0.0145 - val_root_mean_squared_error: 0.0276
# Epoch 93/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0130 - mean_absolute_error: 0.0130 - root_mean_squared_error: 0.0293 - val_loss: 0.0148 - val_mean_absolute_error: 0.0148 - val_root_mean_squared_error: 0.0278
# Epoch 94/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0127 - mean_absolute_error: 0.0127 - root_mean_squared_error: 0.0292 - val_loss: 0.0142 - val_mean_absolute_error: 0.0142 - val_root_mean_squared_error: 0.0275
# Epoch 95/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0126 - mean_absolute_error: 0.0126 - root_mean_squared_error: 0.0292 - val_loss: 0.0147 - val_mean_absolute_error: 0.0147 - val_root_mean_squared_error: 0.0276
# Epoch 96/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0127 - mean_absolute_error: 0.0127 - root_mean_squared_error: 0.0292 - val_loss: 0.0145 - val_mean_absolute_error: 0.0145 - val_root_mean_squared_error: 0.0276
# Epoch 97/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0128 - mean_absolute_error: 0.0128 - root_mean_squared_error: 0.0292 - val_loss: 0.0144 - val_mean_absolute_error: 0.0144 - val_root_mean_squared_error: 0.0274
# Epoch 98/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0127 - mean_absolute_error: 0.0127 - root_mean_squared_error: 0.0291 - val_loss: 0.0146 - val_mean_absolute_error: 0.0146 - val_root_mean_squared_error: 0.0277
# Epoch 99/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0127 - mean_absolute_error: 0.0127 - root_mean_squared_error: 0.0291 - val_loss: 0.0141 - val_mean_absolute_error: 0.0141 - val_root_mean_squared_error: 0.0274
# Epoch 100/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0128 - mean_absolute_error: 0.0128 - root_mean_squared_error: 0.0292 - val_loss: 0.0141 - val_mean_absolute_error: 0.0141 - val_root_mean_squared_error: 0.0273
# Epoch 101/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0127 - mean_absolute_error: 0.0127 - root_mean_squared_error: 0.0292 - val_loss: 0.0152 - val_mean_absolute_error: 0.0152 - val_root_mean_squared_error: 0.0278
# Epoch 102/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0127 - mean_absolute_error: 0.0127 - root_mean_squared_error: 0.0291 - val_loss: 0.0145 - val_mean_absolute_error: 0.0145 - val_root_mean_squared_error: 0.0275
# Epoch 103/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0129 - mean_absolute_error: 0.0129 - root_mean_squared_error: 0.0292 - val_loss: 0.0140 - val_mean_absolute_error: 0.0140 - val_root_mean_squared_error: 0.0272
# Epoch 104/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - root_mean_squared_error: 0.0290 - val_loss: 0.0138 - val_mean_absolute_error: 0.0138 - val_root_mean_squared_error: 0.0272
# Epoch 105/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0127 - mean_absolute_error: 0.0127 - root_mean_squared_error: 0.0291 - val_loss: 0.0144 - val_mean_absolute_error: 0.0144 - val_root_mean_squared_error: 0.0276
# Epoch 106/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0127 - mean_absolute_error: 0.0127 - root_mean_squared_error: 0.0291 - val_loss: 0.0146 - val_mean_absolute_error: 0.0146 - val_root_mean_squared_error: 0.0276
# Epoch 107/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - root_mean_squared_error: 0.0290 - val_loss: 0.0137 - val_mean_absolute_error: 0.0137 - val_root_mean_squared_error: 0.0271
# Epoch 108/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0126 - mean_absolute_error: 0.0126 - root_mean_squared_error: 0.0290 - val_loss: 0.0142 - val_mean_absolute_error: 0.0142 - val_root_mean_squared_error: 0.0274
# Epoch 109/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0126 - mean_absolute_error: 0.0126 - root_mean_squared_error: 0.0290 - val_loss: 0.0140 - val_mean_absolute_error: 0.0140 - val_root_mean_squared_error: 0.0272
# Epoch 110/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - root_mean_squared_error: 0.0290 - val_loss: 0.0144 - val_mean_absolute_error: 0.0144 - val_root_mean_squared_error: 0.0273
# Epoch 111/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - root_mean_squared_error: 0.0289 - val_loss: 0.0139 - val_mean_absolute_error: 0.0139 - val_root_mean_squared_error: 0.0271
# Epoch 112/5000
# 123/123 [==============================] - 2s 12ms/step - loss: 0.0126 - mean_absolute_error: 0.0126 - root_mean_squared_error: 0.0290 - val_loss: 0.0141 - val_mean_absolute_error: 0.0141 - val_root_mean_squared_error: 0.0272
# Epoch 113/5000
# 123/123 [==============================] - 2s 12ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - root_mean_squared_error: 0.0289 - val_loss: 0.0135 - val_mean_absolute_error: 0.0135 - val_root_mean_squared_error: 0.0269
# Epoch 114/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - root_mean_squared_error: 0.0288 - val_loss: 0.0138 - val_mean_absolute_error: 0.0138 - val_root_mean_squared_error: 0.0271
# Epoch 115/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - root_mean_squared_error: 0.0289 - val_loss: 0.0137 - val_mean_absolute_error: 0.0137 - val_root_mean_squared_error: 0.0271
# Epoch 116/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - root_mean_squared_error: 0.0290 - val_loss: 0.0148 - val_mean_absolute_error: 0.0148 - val_root_mean_squared_error: 0.0279
# Epoch 117/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - root_mean_squared_error: 0.0289 - val_loss: 0.0144 - val_mean_absolute_error: 0.0144 - val_root_mean_squared_error: 0.0274
# Epoch 118/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - root_mean_squared_error: 0.0288 - val_loss: 0.0140 - val_mean_absolute_error: 0.0140 - val_root_mean_squared_error: 0.0271
# Epoch 119/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - root_mean_squared_error: 0.0289 - val_loss: 0.0137 - val_mean_absolute_error: 0.0137 - val_root_mean_squared_error: 0.0271
# Epoch 120/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - root_mean_squared_error: 0.0289 - val_loss: 0.0143 - val_mean_absolute_error: 0.0143 - val_root_mean_squared_error: 0.0273
# Epoch 121/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - root_mean_squared_error: 0.0288 - val_loss: 0.0136 - val_mean_absolute_error: 0.0136 - val_root_mean_squared_error: 0.0269
# Epoch 122/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - root_mean_squared_error: 0.0289 - val_loss: 0.0141 - val_mean_absolute_error: 0.0141 - val_root_mean_squared_error: 0.0272
# Epoch 123/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - root_mean_squared_error: 0.0288 - val_loss: 0.0137 - val_mean_absolute_error: 0.0137 - val_root_mean_squared_error: 0.0269
# Epoch 124/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - root_mean_squared_error: 0.0288 - val_loss: 0.0135 - val_mean_absolute_error: 0.0135 - val_root_mean_squared_error: 0.0269
# Epoch 125/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - root_mean_squared_error: 0.0288 - val_loss: 0.0136 - val_mean_absolute_error: 0.0136 - val_root_mean_squared_error: 0.0268
# Epoch 126/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - root_mean_squared_error: 0.0288 - val_loss: 0.0133 - val_mean_absolute_error: 0.0133 - val_root_mean_squared_error: 0.0268
# Epoch 127/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - root_mean_squared_error: 0.0287 - val_loss: 0.0135 - val_mean_absolute_error: 0.0135 - val_root_mean_squared_error: 0.0268
# Epoch 128/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - root_mean_squared_error: 0.0287 - val_loss: 0.0136 - val_mean_absolute_error: 0.0136 - val_root_mean_squared_error: 0.0269
# Epoch 129/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - root_mean_squared_error: 0.0287 - val_loss: 0.0133 - val_mean_absolute_error: 0.0133 - val_root_mean_squared_error: 0.0266
# Epoch 130/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - root_mean_squared_error: 0.0287 - val_loss: 0.0134 - val_mean_absolute_error: 0.0134 - val_root_mean_squared_error: 0.0268
# Epoch 131/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - root_mean_squared_error: 0.0287 - val_loss: 0.0148 - val_mean_absolute_error: 0.0148 - val_root_mean_squared_error: 0.0277
# Epoch 132/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - root_mean_squared_error: 0.0287 - val_loss: 0.0133 - val_mean_absolute_error: 0.0133 - val_root_mean_squared_error: 0.0267
# Epoch 133/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - root_mean_squared_error: 0.0287 - val_loss: 0.0134 - val_mean_absolute_error: 0.0134 - val_root_mean_squared_error: 0.0266
# Epoch 134/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - root_mean_squared_error: 0.0287 - val_loss: 0.0136 - val_mean_absolute_error: 0.0136 - val_root_mean_squared_error: 0.0268
# Epoch 135/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - root_mean_squared_error: 0.0287 - val_loss: 0.0137 - val_mean_absolute_error: 0.0137 - val_root_mean_squared_error: 0.0270
# Epoch 136/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - root_mean_squared_error: 0.0287 - val_loss: 0.0133 - val_mean_absolute_error: 0.0133 - val_root_mean_squared_error: 0.0267
# Epoch 137/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - root_mean_squared_error: 0.0286 - val_loss: 0.0144 - val_mean_absolute_error: 0.0144 - val_root_mean_squared_error: 0.0273
# Epoch 138/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - root_mean_squared_error: 0.0287 - val_loss: 0.0129 - val_mean_absolute_error: 0.0129 - val_root_mean_squared_error: 0.0265
# Epoch 139/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - root_mean_squared_error: 0.0286 - val_loss: 0.0133 - val_mean_absolute_error: 0.0133 - val_root_mean_squared_error: 0.0266
# Epoch 140/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - root_mean_squared_error: 0.0287 - val_loss: 0.0140 - val_mean_absolute_error: 0.0140 - val_root_mean_squared_error: 0.0270
# Epoch 141/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - root_mean_squared_error: 0.0286 - val_loss: 0.0135 - val_mean_absolute_error: 0.0135 - val_root_mean_squared_error: 0.0267
# Epoch 142/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - root_mean_squared_error: 0.0286 - val_loss: 0.0139 - val_mean_absolute_error: 0.0139 - val_root_mean_squared_error: 0.0269
# Epoch 143/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - root_mean_squared_error: 0.0287 - val_loss: 0.0135 - val_mean_absolute_error: 0.0135 - val_root_mean_squared_error: 0.0267
# Epoch 144/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - root_mean_squared_error: 0.0286 - val_loss: 0.0132 - val_mean_absolute_error: 0.0132 - val_root_mean_squared_error: 0.0265
# Epoch 145/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - root_mean_squared_error: 0.0286 - val_loss: 0.0135 - val_mean_absolute_error: 0.0135 - val_root_mean_squared_error: 0.0267
# Epoch 146/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - root_mean_squared_error: 0.0286 - val_loss: 0.0132 - val_mean_absolute_error: 0.0132 - val_root_mean_squared_error: 0.0266
# Epoch 147/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - root_mean_squared_error: 0.0286 - val_loss: 0.0131 - val_mean_absolute_error: 0.0131 - val_root_mean_squared_error: 0.0265
# Epoch 148/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - root_mean_squared_error: 0.0285 - val_loss: 0.0129 - val_mean_absolute_error: 0.0129 - val_root_mean_squared_error: 0.0263
# Epoch 149/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - root_mean_squared_error: 0.0285 - val_loss: 0.0132 - val_mean_absolute_error: 0.0132 - val_root_mean_squared_error: 0.0265
# Epoch 150/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - root_mean_squared_error: 0.0285 - val_loss: 0.0136 - val_mean_absolute_error: 0.0136 - val_root_mean_squared_error: 0.0268
# Epoch 151/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - root_mean_squared_error: 0.0285 - val_loss: 0.0137 - val_mean_absolute_error: 0.0137 - val_root_mean_squared_error: 0.0267
# Epoch 152/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - root_mean_squared_error: 0.0285 - val_loss: 0.0131 - val_mean_absolute_error: 0.0131 - val_root_mean_squared_error: 0.0266
# Epoch 153/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - root_mean_squared_error: 0.0286 - val_loss: 0.0132 - val_mean_absolute_error: 0.0132 - val_root_mean_squared_error: 0.0266
# Epoch 154/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - root_mean_squared_error: 0.0285 - val_loss: 0.0130 - val_mean_absolute_error: 0.0130 - val_root_mean_squared_error: 0.0264
# Epoch 155/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - root_mean_squared_error: 0.0285 - val_loss: 0.0131 - val_mean_absolute_error: 0.0131 - val_root_mean_squared_error: 0.0264
# Epoch 156/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - root_mean_squared_error: 0.0285 - val_loss: 0.0139 - val_mean_absolute_error: 0.0139 - val_root_mean_squared_error: 0.0269
# Epoch 157/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - root_mean_squared_error: 0.0285 - val_loss: 0.0128 - val_mean_absolute_error: 0.0128 - val_root_mean_squared_error: 0.0263
# Epoch 158/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - root_mean_squared_error: 0.0285 - val_loss: 0.0130 - val_mean_absolute_error: 0.0130 - val_root_mean_squared_error: 0.0264
# Epoch 159/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - root_mean_squared_error: 0.0284 - val_loss: 0.0132 - val_mean_absolute_error: 0.0132 - val_root_mean_squared_error: 0.0264
# Epoch 160/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - root_mean_squared_error: 0.0285 - val_loss: 0.0136 - val_mean_absolute_error: 0.0136 - val_root_mean_squared_error: 0.0267
# Epoch 161/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - root_mean_squared_error: 0.0285 - val_loss: 0.0128 - val_mean_absolute_error: 0.0128 - val_root_mean_squared_error: 0.0262
# Epoch 162/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - root_mean_squared_error: 0.0284 - val_loss: 0.0128 - val_mean_absolute_error: 0.0128 - val_root_mean_squared_error: 0.0263
# Epoch 163/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - root_mean_squared_error: 0.0284 - val_loss: 0.0129 - val_mean_absolute_error: 0.0129 - val_root_mean_squared_error: 0.0264
# Epoch 164/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - root_mean_squared_error: 0.0285 - val_loss: 0.0131 - val_mean_absolute_error: 0.0131 - val_root_mean_squared_error: 0.0264
# Epoch 165/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - root_mean_squared_error: 0.0285 - val_loss: 0.0129 - val_mean_absolute_error: 0.0129 - val_root_mean_squared_error: 0.0264
# Epoch 166/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - root_mean_squared_error: 0.0285 - val_loss: 0.0137 - val_mean_absolute_error: 0.0137 - val_root_mean_squared_error: 0.0267
# Epoch 167/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - root_mean_squared_error: 0.0284 - val_loss: 0.0133 - val_mean_absolute_error: 0.0133 - val_root_mean_squared_error: 0.0265
# Epoch 168/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - root_mean_squared_error: 0.0284 - val_loss: 0.0129 - val_mean_absolute_error: 0.0129 - val_root_mean_squared_error: 0.0264
# Epoch 169/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - root_mean_squared_error: 0.0284 - val_loss: 0.0127 - val_mean_absolute_error: 0.0127 - val_root_mean_squared_error: 0.0262
# Epoch 170/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - root_mean_squared_error: 0.0283 - val_loss: 0.0128 - val_mean_absolute_error: 0.0128 - val_root_mean_squared_error: 0.0263
# Epoch 171/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - root_mean_squared_error: 0.0283 - val_loss: 0.0131 - val_mean_absolute_error: 0.0131 - val_root_mean_squared_error: 0.0264
# Epoch 172/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - root_mean_squared_error: 0.0284 - val_loss: 0.0136 - val_mean_absolute_error: 0.0136 - val_root_mean_squared_error: 0.0267
# Epoch 173/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - root_mean_squared_error: 0.0284 - val_loss: 0.0137 - val_mean_absolute_error: 0.0137 - val_root_mean_squared_error: 0.0268
# Epoch 174/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - root_mean_squared_error: 0.0284 - val_loss: 0.0128 - val_mean_absolute_error: 0.0128 - val_root_mean_squared_error: 0.0263
# Epoch 175/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - root_mean_squared_error: 0.0284 - val_loss: 0.0127 - val_mean_absolute_error: 0.0127 - val_root_mean_squared_error: 0.0261
# Epoch 176/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - root_mean_squared_error: 0.0283 - val_loss: 0.0137 - val_mean_absolute_error: 0.0137 - val_root_mean_squared_error: 0.0268
# Epoch 177/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - root_mean_squared_error: 0.0283 - val_loss: 0.0127 - val_mean_absolute_error: 0.0127 - val_root_mean_squared_error: 0.0262
# Epoch 178/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - root_mean_squared_error: 0.0283 - val_loss: 0.0126 - val_mean_absolute_error: 0.0126 - val_root_mean_squared_error: 0.0261
# Epoch 179/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - root_mean_squared_error: 0.0283 - val_loss: 0.0128 - val_mean_absolute_error: 0.0128 - val_root_mean_squared_error: 0.0262
# Epoch 180/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - root_mean_squared_error: 0.0283 - val_loss: 0.0132 - val_mean_absolute_error: 0.0132 - val_root_mean_squared_error: 0.0264
# Epoch 181/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - root_mean_squared_error: 0.0283 - val_loss: 0.0127 - val_mean_absolute_error: 0.0127 - val_root_mean_squared_error: 0.0262
# Epoch 182/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - root_mean_squared_error: 0.0283 - val_loss: 0.0130 - val_mean_absolute_error: 0.0130 - val_root_mean_squared_error: 0.0262
# Epoch 183/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - root_mean_squared_error: 0.0283 - val_loss: 0.0136 - val_mean_absolute_error: 0.0136 - val_root_mean_squared_error: 0.0265
# Epoch 184/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - root_mean_squared_error: 0.0283 - val_loss: 0.0126 - val_mean_absolute_error: 0.0126 - val_root_mean_squared_error: 0.0262
# Epoch 185/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - root_mean_squared_error: 0.0283 - val_loss: 0.0128 - val_mean_absolute_error: 0.0128 - val_root_mean_squared_error: 0.0261
# Epoch 186/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - root_mean_squared_error: 0.0282 - val_loss: 0.0129 - val_mean_absolute_error: 0.0129 - val_root_mean_squared_error: 0.0262
# Epoch 187/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - root_mean_squared_error: 0.0283 - val_loss: 0.0129 - val_mean_absolute_error: 0.0129 - val_root_mean_squared_error: 0.0263
# Epoch 188/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0113 - mean_absolute_error: 0.0113 - root_mean_squared_error: 0.0282 - val_loss: 0.0126 - val_mean_absolute_error: 0.0126 - val_root_mean_squared_error: 0.0261
# Epoch 189/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - root_mean_squared_error: 0.0282 - val_loss: 0.0126 - val_mean_absolute_error: 0.0126 - val_root_mean_squared_error: 0.0260
# Epoch 190/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - root_mean_squared_error: 0.0282 - val_loss: 0.0129 - val_mean_absolute_error: 0.0129 - val_root_mean_squared_error: 0.0263
# Epoch 191/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - root_mean_squared_error: 0.0282 - val_loss: 0.0129 - val_mean_absolute_error: 0.0129 - val_root_mean_squared_error: 0.0262
# Epoch 192/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - root_mean_squared_error: 0.0282 - val_loss: 0.0126 - val_mean_absolute_error: 0.0126 - val_root_mean_squared_error: 0.0261
# Epoch 193/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - root_mean_squared_error: 0.0283 - val_loss: 0.0129 - val_mean_absolute_error: 0.0129 - val_root_mean_squared_error: 0.0262
# Epoch 194/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - root_mean_squared_error: 0.0282 - val_loss: 0.0137 - val_mean_absolute_error: 0.0137 - val_root_mean_squared_error: 0.0266
# Epoch 195/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - root_mean_squared_error: 0.0282 - val_loss: 0.0125 - val_mean_absolute_error: 0.0125 - val_root_mean_squared_error: 0.0260
# Epoch 196/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - root_mean_squared_error: 0.0282 - val_loss: 0.0127 - val_mean_absolute_error: 0.0127 - val_root_mean_squared_error: 0.0262
# Epoch 197/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - root_mean_squared_error: 0.0282 - val_loss: 0.0134 - val_mean_absolute_error: 0.0134 - val_root_mean_squared_error: 0.0264
# Epoch 198/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - root_mean_squared_error: 0.0282 - val_loss: 0.0130 - val_mean_absolute_error: 0.0130 - val_root_mean_squared_error: 0.0263
# Epoch 199/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0113 - mean_absolute_error: 0.0113 - root_mean_squared_error: 0.0282 - val_loss: 0.0127 - val_mean_absolute_error: 0.0127 - val_root_mean_squared_error: 0.0261
# Epoch 200/5000
# ...
# Epoch 251/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0111 - mean_absolute_error: 0.0111 - root_mean_squared_error: 0.0280 - val_loss: 0.0127 - val_mean_absolute_error: 0.0127 - val_root_mean_squared_error: 0.0260
# Epoch 252/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - root_mean_squared_error: 0.0279 - val_loss: 0.0126 - val_mean_absolute_error: 0.0126 - val_root_mean_squared_error: 0.0259
# Epoch 253/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0279 - val_loss: 0.0120 - val_mean_absolute_error: 0.0120 - val_root_mean_squared_error: 0.0257
# Epoch 254/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0111 - mean_absolute_error: 0.0111 - root_mean_squared_error: 0.0280 - val_loss: 0.0122 - val_mean_absolute_error: 0.0122 - val_root_mean_squared_error: 0.0258
# Epoch 255/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0111 - mean_absolute_error: 0.0111 - root_mean_squared_error: 0.0279 - val_loss: 0.0123 - val_mean_absolute_error: 0.0123 - val_root_mean_squared_error: 0.0258
# Epoch 256/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0111 - mean_absolute_error: 0.0111 - root_mean_squared_error: 0.0279 - val_loss: 0.0134 - val_mean_absolute_error: 0.0134 - val_root_mean_squared_error: 0.0264
# Epoch 257/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - root_mean_squared_error: 0.0279 - val_loss: 0.0121 - val_mean_absolute_error: 0.0121 - val_root_mean_squared_error: 0.0256
# Epoch 258/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0279 - val_loss: 0.0121 - val_mean_absolute_error: 0.0121 - val_root_mean_squared_error: 0.0257
# Epoch 259/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - root_mean_squared_error: 0.0279 - val_loss: 0.0123 - val_mean_absolute_error: 0.0123 - val_root_mean_squared_error: 0.0258
# Epoch 260/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0112 - mean_absolute_error: 0.0112 - root_mean_squared_error: 0.0280 - val_loss: 0.0122 - val_mean_absolute_error: 0.0122 - val_root_mean_squared_error: 0.0257
# Epoch 261/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0111 - mean_absolute_error: 0.0111 - root_mean_squared_error: 0.0279 - val_loss: 0.0122 - val_mean_absolute_error: 0.0122 - val_root_mean_squared_error: 0.0257
# Epoch 262/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - root_mean_squared_error: 0.0279 - val_loss: 0.0125 - val_mean_absolute_error: 0.0125 - val_root_mean_squared_error: 0.0258
# Epoch 263/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - root_mean_squared_error: 0.0279 - val_loss: 0.0121 - val_mean_absolute_error: 0.0121 - val_root_mean_squared_error: 0.0257
# Epoch 264/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - root_mean_squared_error: 0.0279 - val_loss: 0.0124 - val_mean_absolute_error: 0.0124 - val_root_mean_squared_error: 0.0259
# Epoch 265/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0278 - val_loss: 0.0123 - val_mean_absolute_error: 0.0123 - val_root_mean_squared_error: 0.0257
# Epoch 266/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - root_mean_squared_error: 0.0279 - val_loss: 0.0119 - val_mean_absolute_error: 0.0119 - val_root_mean_squared_error: 0.0256
# Epoch 267/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - root_mean_squared_error: 0.0279 - val_loss: 0.0122 - val_mean_absolute_error: 0.0122 - val_root_mean_squared_error: 0.0257
# Epoch 268/5000
# 123/123 [==============================] - 2s 13ms/step - loss: 0.0111 - mean_absolute_error: 0.0111 - root_mean_squared_error: 0.0279 - val_loss: 0.0127 - val_mean_absolute_error: 0.0127 - val_root_mean_squared_error: 0.0260
# Epoch 269/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0112 - mean_absolute_error: 0.0112 - root_mean_squared_error: 0.0280 - val_loss: 0.0121 - val_mean_absolute_error: 0.0121 - val_root_mean_squared_error: 0.0257
# Epoch 270/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0278 - val_loss: 0.0124 - val_mean_absolute_error: 0.0124 - val_root_mean_squared_error: 0.0257
# Epoch 271/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0278 - val_loss: 0.0124 - val_mean_absolute_error: 0.0124 - val_root_mean_squared_error: 0.0258
# Epoch 272/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - root_mean_squared_error: 0.0279 - val_loss: 0.0119 - val_mean_absolute_error: 0.0119 - val_root_mean_squared_error: 0.0255
# Epoch 273/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0278 - val_loss: 0.0125 - val_mean_absolute_error: 0.0125 - val_root_mean_squared_error: 0.0258
# Epoch 274/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0278 - val_loss: 0.0125 - val_mean_absolute_error: 0.0125 - val_root_mean_squared_error: 0.0257
# Epoch 275/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0278 - val_loss: 0.0121 - val_mean_absolute_error: 0.0121 - val_root_mean_squared_error: 0.0256
# Epoch 276/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - root_mean_squared_error: 0.0279 - val_loss: 0.0123 - val_mean_absolute_error: 0.0123 - val_root_mean_squared_error: 0.0257
# Epoch 277/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - root_mean_squared_error: 0.0279 - val_loss: 0.0136 - val_mean_absolute_error: 0.0136 - val_root_mean_squared_error: 0.0265
# Epoch 278/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0278 - val_loss: 0.0122 - val_mean_absolute_error: 0.0122 - val_root_mean_squared_error: 0.0257
# Epoch 279/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0111 - mean_absolute_error: 0.0111 - root_mean_squared_error: 0.0279 - val_loss: 0.0137 - val_mean_absolute_error: 0.0137 - val_root_mean_squared_error: 0.0264
# Epoch 280/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - root_mean_squared_error: 0.0278 - val_loss: 0.0120 - val_mean_absolute_error: 0.0120 - val_root_mean_squared_error: 0.0255
# Epoch 281/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0278 - val_loss: 0.0128 - val_mean_absolute_error: 0.0128 - val_root_mean_squared_error: 0.0258
# Epoch 282/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0278 - val_loss: 0.0119 - val_mean_absolute_error: 0.0119 - val_root_mean_squared_error: 0.0256
# Epoch 283/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0278 - val_loss: 0.0123 - val_mean_absolute_error: 0.0123 - val_root_mean_squared_error: 0.0257
# Epoch 284/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0278 - val_loss: 0.0123 - val_mean_absolute_error: 0.0123 - val_root_mean_squared_error: 0.0257
# Epoch 285/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0278 - val_loss: 0.0120 - val_mean_absolute_error: 0.0120 - val_root_mean_squared_error: 0.0256
# Epoch 286/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0278 - val_loss: 0.0121 - val_mean_absolute_error: 0.0121 - val_root_mean_squared_error: 0.0256
# Epoch 287/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0278 - val_loss: 0.0121 - val_mean_absolute_error: 0.0121 - val_root_mean_squared_error: 0.0256
# Epoch 288/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0278 - val_loss: 0.0123 - val_mean_absolute_error: 0.0123 - val_root_mean_squared_error: 0.0257
# Epoch 289/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0278 - val_loss: 0.0120 - val_mean_absolute_error: 0.0120 - val_root_mean_squared_error: 0.0256
# Epoch 290/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0278 - val_loss: 0.0118 - val_mean_absolute_error: 0.0118 - val_root_mean_squared_error: 0.0254
# Epoch 291/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0278 - val_loss: 0.0118 - val_mean_absolute_error: 0.0118 - val_root_mean_squared_error: 0.0255
# Epoch 292/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - root_mean_squared_error: 0.0277 - val_loss: 0.0121 - val_mean_absolute_error: 0.0121 - val_root_mean_squared_error: 0.0256
# Epoch 293/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0278 - val_loss: 0.0118 - val_mean_absolute_error: 0.0118 - val_root_mean_squared_error: 0.0255
# Epoch 294/5000
# 123/123 [==============================] - 2s 16ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - root_mean_squared_error: 0.0277 - val_loss: 0.0121 - val_mean_absolute_error: 0.0121 - val_root_mean_squared_error: 0.0256
# Epoch 295/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0277 - val_loss: 0.0130 - val_mean_absolute_error: 0.0130 - val_root_mean_squared_error: 0.0260
# Epoch 296/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0278 - val_loss: 0.0121 - val_mean_absolute_error: 0.0121 - val_root_mean_squared_error: 0.0256
# Epoch 297/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0277 - val_loss: 0.0123 - val_mean_absolute_error: 0.0123 - val_root_mean_squared_error: 0.0257
# Epoch 298/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0278 - val_loss: 0.0120 - val_mean_absolute_error: 0.0120 - val_root_mean_squared_error: 0.0256
# Epoch 299/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0278 - val_loss: 0.0123 - val_mean_absolute_error: 0.0123 - val_root_mean_squared_error: 0.0256
# Epoch 300/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0278 - val_loss: 0.0124 - val_mean_absolute_error: 0.0124 - val_root_mean_squared_error: 0.0257
# Epoch 301/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0278 - val_loss: 0.0123 - val_mean_absolute_error: 0.0123 - val_root_mean_squared_error: 0.0257
# Epoch 302/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - root_mean_squared_error: 0.0278 - val_loss: 0.0118 - val_mean_absolute_error: 0.0118 - val_root_mean_squared_error: 0.0255
# Epoch 303/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0277 - val_loss: 0.0121 - val_mean_absolute_error: 0.0121 - val_root_mean_squared_error: 0.0257
# Epoch 304/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0278 - val_loss: 0.0120 - val_mean_absolute_error: 0.0120 - val_root_mean_squared_error: 0.0256
# Epoch 305/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - root_mean_squared_error: 0.0278 - val_loss: 0.0121 - val_mean_absolute_error: 0.0121 - val_root_mean_squared_error: 0.0256
# Epoch 306/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0278 - val_loss: 0.0121 - val_mean_absolute_error: 0.0121 - val_root_mean_squared_error: 0.0256
# Epoch 307/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0278 - val_loss: 0.0131 - val_mean_absolute_error: 0.0131 - val_root_mean_squared_error: 0.0260
# Epoch 308/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0277 - val_loss: 0.0121 - val_mean_absolute_error: 0.0121 - val_root_mean_squared_error: 0.0255
# Epoch 309/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0277 - val_loss: 0.0120 - val_mean_absolute_error: 0.0120 - val_root_mean_squared_error: 0.0255
# Epoch 310/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0277 - val_loss: 0.0119 - val_mean_absolute_error: 0.0119 - val_root_mean_squared_error: 0.0255
# Epoch 311/5000
# 123/123 [==============================] - 2s 16ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - root_mean_squared_error: 0.0277 - val_loss: 0.0124 - val_mean_absolute_error: 0.0124 - val_root_mean_squared_error: 0.0258
# Epoch 312/5000
# 123/123 [==============================] - 2s 14ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0277 - val_loss: 0.0122 - val_mean_absolute_error: 0.0122 - val_root_mean_squared_error: 0.0256
# Epoch 313/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - root_mean_squared_error: 0.0277 - val_loss: 0.0118 - val_mean_absolute_error: 0.0118 - val_root_mean_squared_error: 0.0255
# Epoch 314/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0277 - val_loss: 0.0119 - val_mean_absolute_error: 0.0119 - val_root_mean_squared_error: 0.0254
# Epoch 315/5000
# 123/123 [==============================] - 2s 15ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0278 - val_loss: 0.0119 - val_mean_absolute_error: 0.0119 - val_root_mean_squared_error: 0.0254
# Epoch 316/5000
# 123/123 [==============================] - 2s 16ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - root_mean_squared_error: 0.0277 - val_loss: 0.0121 - val_mean_absolute_error: 0.0121 - val_root_mean_squared_error: 0.0256

# %%
# plot model convergence
plt.figure(figsize = (15,4))
plt.semilogy(hist.history['loss'], color = 'black')
plt.semilogy(hist.history['val_loss'], color = 'blue')
plt.tick_params(labelsize = 14)

plt.title('Model Loss', fontsize = 20)
plt.ylabel('Loss (MAE)', fontsize = 16)
plt.xlabel('Epoch', fontsize = 16)
plt.legend(['train', 'validation'], loc='upper right', frameon = False, 
           fontsize = 14)

plt.tight_layout()
plt.show()

# %%
# evaluate Kiholo model
# prediction for Kiholo data (with train/validation split)
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)
y_pred = np.concatenate((y_train_pred,y_test_pred), axis = 0)

test_loss_a = model.evaluate(X_train, y_train)
test_loss_b = model.evaluate(X_test, y_test)

print(test_loss_a)
print(test_loss_b)
# Out:
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - root_mean_squared_error: 0.0277
# 96/96 [==============================] - 0s 3ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - root_mean_squared_error: 0.0256
# [0.010868997313082218, 0.010868997313082218, 0.027737101539969444]
# [0.012080864980816841, 0.012080864980816841, 0.0255535040050745]

# %%
# Kiholo training and validation r^2
R2_train = r2_score(y_train[:,3], y_train_pred[:,3], 
                    multioutput = 'variance_weighted')

R2_test = r2_score(y_test[:,3], y_test_pred[:,3], 
                   multioutput = 'variance_weighted')

print(R2_train)
print(R2_test)
# Out:
# 0.9713919575943437
# 0.9272280662125243

# %%
# y vs y pred 45 degree mismatch for Kiholo (with train/validation split)
plt.figure(figsize = (8,8))
plt.scatter(y_train_pred[:,3], y_train[:,3], alpha = 1, label = 'train', color = 'navy')#, color = 'lightblue')
plt.scatter(y_test_pred[:,3], y_test[:,3], alpha = 1, label = 'validation', marker ='x', color = 'slateblue')#, color = 'darkblue')

plt.legend(loc = 'lower right', frameon=False, fontsize = 14)
plt.xlabel('Normalized $^{222}$Rn (predicted)', fontsize = 16)
plt.ylabel('Normalized $^{222}$Rn (observed)', fontsize = 16)
plt.title('Kīholo Bay, HI (Rocky)', fontsize = 20)
 
# plot 45 degree line
x1 = np.linspace(0, 1, 1000)
plt.plot(x1,x1, c = "red") 

plt.tick_params(labelsize = 14)

# plot r2 results on plot
plt.text(0.001, 0.98, '$r^2$ (train) = %0.2f' % R2_train, fontsize = 14)
plt.text(0.001, 0.94, '$r^2$ (validation) = %0.2f' % R2_test, fontsize = 14)
plt.tight_layout()
plt.show()

# %%
# plot predicted Rn with respect to time
plt.figure(figsize=(10, 3))
plt.plot(y[:,3], label='observed', color = 'navy')
plt.plot(y_pred[:,3], label='predicted', linestyle = 'dashed', linewidth = 2, 
         color = 'slateblue')

plt.vlines(12000, -0.05, 1.05, colors='k', linestyles='dotted', label='train/validation split')

plt.tick_params(labelsize = 14)

plt.title('Kīholo Bay (Rocky)', fontsize = 20)
plt.ylabel('Normalized $^{222}$Rn', fontsize = 16)

plt.legend(bbox_to_anchor=(.5, 1.05), fontsize = 14, frameon = False)
plt.xlim(-15, 13570)
plt.ylim(-0.05, 1.05)
plt.tight_layout()
plt.show()

# %% [markdown]
# # FSUCML SGD Validation (Example)
#
# Data source: Santos, I. R., Burnett, W. C., Chanton, J., Dimova, N., & Peterson, R. N. (2009). Land or ocean?: Assessing the driving forces of submarine groundwater discharge at a coastal site in the gulf of mexico. Journal of Geophysical Research: Oceans, 114(4), 1–11. https://doi.org/10.1029/2008JC005038
#
# Meteorological data source: FAWN (Florida Automated Weather Network (FAWN). Carrabell Station. https://fawn.ifas.ufl.edu/data/reports/
#
# Example code that can be modified for other datasets, gap filling, etc.

# %%
# import Florida Rn dataset
FL_raw = pd.read_excel('/content/drive/My Drive/CEE696/FSUCML_Rn_clean.xlsx')

FL_raw.columns = ['datetime', 'owl_m', 'CTDtemp_C', 'CTDsal', 'Rn_Bqm3']

# convert first column to datetime format
FL_raw.datetime = pd.to_datetime(FL_raw.datetime)

# index by datetime
FL_raw.set_index(FL_raw.datetime, inplace = True)

# index by datetime
FL_raw.set_index(FL_raw.datetime, inplace = True)
FL_raw = FL_raw.drop('datetime', axis = 1)

FL = FL_raw

# pre-processing: 12 hour MA 
FL_12hr =  FL.rolling(window = 12, center = True).mean()

FL_12hr = FL_12hr.dropna()
FL_12hr.head()
# Out:
#                         owl_m  CTDtemp_C     CTDsal    Rn_Bqm3
# datetime
# 2005-11-18 20:09:00  1.397233  16.474583  33.678333  44.576667
# 2005-11-18 21:09:00  1.432070  16.315417  33.711167  49.540833
# 2005-11-18 22:09:00  1.461615  16.140417  33.727333  54.666667
# 2005-11-18 23:09:00  1.478037  15.949583  33.738667  55.549167
# 2005-11-19 00:09:00  1.484471  15.774583  33.748667  56.007500

# %%
# check minimum values, rescale if necessary
FL_12hr.min()
# Out:
# owl_m         0.829202
# CTDtemp_C    10.155625
# CTDsal       24.947167
# Rn_Bqm3       0.000000
# dtype: float64

# %%
# normalize FL data
FL_norm = FL_12hr
FL_norm['owl_m'] = (FL_12hr['owl_m'] - min(FL_12hr['owl_m'])) / (max(FL_12hr['owl_m']) - min(FL_12hr['owl_m']))
FL_norm['CTDtemp_C'] = (FL_12hr['CTDtemp_C'] - min(FL_12hr['CTDtemp_C'])) / (max(FL_12hr['CTDtemp_C']) - min(FL_12hr['CTDtemp_C']))
FL_norm['CTDsal'] = (FL_12hr['CTDsal'] - min(FL_12hr['CTDsal'])) / (max(FL_12hr['CTDsal']) - min(FL_12hr['CTDsal']))
FL_norm['Rn_Bqm3'] = (FL_12hr['Rn_Bqm3'] - min(FL_12hr['Rn_Bqm3'])) / (max(FL_12hr['Rn_Bqm3']) - min(FL_12hr['Rn_Bqm3']))

# %%
# separate input (owl, ctdtemp, salinity) and output (Rn) variables 
FL_norm_y = FL_norm['Rn_Bqm3']
FL_norm = FL_norm.drop(['Rn_Bqm3'], axis = 1)
FL_norm.head()
# Out:
#                         owl_m  CTDtemp_C    CTDsal
# datetime
# 2005-11-18 20:09:00  0.323876   0.239066  0.740805
# 2005-11-18 21:09:00  0.343739   0.233044  0.743591
# 2005-11-18 22:09:00  0.360585   0.226423  0.744962
# 2005-11-18 23:09:00  0.369948   0.219203  0.745924
# 2005-11-19 00:09:00  0.373617   0.212583  0.746772

# %%
# code modified from "Deep Learning for Time Series Forecasting: Predict the Future with MLPs, CNNs and LSTMs in Python" by Jason Brownlee
# https://machinelearningmastery.com/deep-learning-for-time-series-forecasting/

# split Florida multivariate sequence into samples
def split_sequences(sequences, n_steps_in, n_steps_out):
  X_FL, y_FL = list(), list()
  for i in range(len(sequences)):
    # find the end of this pattern
    end_ix = i + n_steps_in
    out_end_ix = end_ix + n_steps_out
    # check if we are beyond the dataset
    if out_end_ix > len(sequences):
      break
    # gather input and output parts of the pattern
    seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix:out_end_ix, :]
    X_FL.append(seq_x)
    y_FL.append(seq_y)
  return array(X_FL), array(y_FL)

# input sequence
in_seq1_FL = FL_norm['owl_m'] .to_numpy()
in_seq2_FL = FL_norm['CTDtemp_C'].to_numpy()
in_seq3_FL = FL_norm['CTDsal'] .to_numpy()

# output
out_seq_FL = FL_norm_y.to_numpy()

# convert to [rows, columns] structure
in_seq1_FL = in_seq1_FL.reshape((len(in_seq1_FL), 1))
in_seq2_FL = in_seq2_FL.reshape((len(in_seq2_FL), 1))
in_seq3_FL = in_seq3_FL.reshape((len(in_seq3_FL), 1))

out_seq_FL = out_seq_FL.reshape((len(out_seq_FL), 1))

# horizontally stack columns
dataset_FL = hstack((in_seq1_FL, in_seq2_FL, in_seq3_FL, out_seq_FL))

# number of time steps
n_steps_in, n_steps_out = 6, 1

# %%
# convert into input/output
X_FL, y_FL = split_sequences(dataset_FL, n_steps_in, n_steps_out)
print(X_FL.shape, y_FL.shape)

# flatten output
n_output = y_FL.shape[1] * y_FL.shape[2]
y_FL = y_FL.reshape((y_FL.shape[0], n_output))

# number of features
n_features = X_FL.shape[2]
# Out:
# (14970, 6, 4) (14970, 1, 4)

# %%
# evaluate Florida dataset using model trained on Kiholo data
y_test_FL = model.predict(X_FL)
test_loss_FL = model.evaluate(X_FL, y_FL[:,3])
print(test_loss_FL)
# Out:
# 468/468 [==============================] - 3s 6ms/step - loss: 0.1641 - mean_absolute_error: 0.1641 - root_mean_squared_error: 0.2322
# [0.16414102911949158, 0.16414102911949158, 0.2322498857975006]

# %%
# r^2
R2_FL = r2_score(y_FL[:,3], y_test_FL[:,3], multioutput = 'variance_weighted')
print(R2_FL)
# Out:
# 0.9930992141408291

# %%
# y vs y pred 45 degree mismatch for data (with train/test split)
plt.figure(figsize = (8,8))

plt.scatter(y_test_FL[:,3], y_FL[:,3], color = 'yellowgreen')

plt.xlabel('Normalized $^{222}$Rn (predicted)', fontsize = 16)
plt.ylabel('Normalized $^{222}$Rn (observed)', fontsize = 16)
plt.title('FSUCML, FL (Sandy)', fontsize = 20)
 
x1 = np.linspace(0, 1, 1000)
plt.plot(x1,x1, c = "red") 
plt.text(0.001, 0.98, '$r^2$ = %0.2f' % R2_FL, fontsize = 14)

plt.tick_params(labelsize = 14)
plt.tight_layout()

plt.show()

# %%
# plot predicted
plt.figure(figsize = (10, 3))

plt.plot(y_FL[:,3], label ='observed', color = 'yellowgreen')
plt.plot(y_test_FL[:,3], 
         label = 'predicted', 
         linestyle = 'dashed', 
         linewidth = 2, 
         color = 'olivedrab')

plt.ylabel('Normalized $^{222}$Rn', fontsize = 16)
plt.title("FSUCML, FL (Sandy)", fontsize = 20)

plt.legend(fontsize = 14, frameon = False)
 
plt.tick_params(labelsize = 14)

#plt.xlim(-15, 3200)
plt.ylim(-0.05, 1.05)
plt.tight_layout()
plt.show()
